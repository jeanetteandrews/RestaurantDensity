# %%
import pandas as pd
import numpy as np
import googlemaps
from pandas.io.json import json_normalize
from fuzzywuzzy import process, fuzz

OSM = pd.read_json('amenities-vancouver.json.gz', lines=True)

pd.options.mode.chained_assignment = None #disable weird warnings

# %%
rest_list = ['cafe', 'fast_food', 'restaurant', 'pub',
       'bar', 'ice_cream', 'bistro', 'juice_bar']
restaurants = OSM[OSM.amenity.isin(rest_list)]
restaurants['name'] = restaurants['name'].str.lower()
restaurants
# Out:
#              lat         lon                      timestamp     amenity  \
# 0      49.260812 -123.125736  2020-03-20T18:22:12.000-07:00        cafe
# 1      49.260953 -123.125704  2019-08-02T18:11:20.000-07:00   fast_food
# 13     49.126650 -123.182470  2020-03-30T09:08:51.000-07:00  restaurant
# 16     49.283192 -123.109050  2015-12-18T21:41:07.000-08:00         pub
# 19     49.265951 -123.246630  2011-11-19T08:06:36.000-08:00         pub
# ...          ...         ...                            ...         ...
# 17712  49.250408 -123.076261  2017-07-08T05:22:57.000-07:00  restaurant
# 17713  49.278424 -122.806704  2013-03-26T23:45:49.000-07:00        cafe
# 17714  49.278770 -122.797628  2013-03-26T23:45:49.000-07:00  restaurant
# 17716  49.282666 -122.826978  2019-09-13T13:56:49.000-07:00         pub
# 17717  49.282420 -122.826340  2019-09-13T13:56:49.000-07:00        cafe
#
#                            name  \
# 0                     starbucks
# 1                    salad loop
# 13     best bite indian cuisine
# 16                   the cambie
# 19              mahony and sons
# ...                         ...
# 17712            house of dosas
# 17713          creekside coffee
# 17714                togo sushi
# 17716      brown's social house
# 17717          gallagher's cafe
#
#                                                     tags
# 0      {'brand:wikidata': 'Q37158', 'official_name': ...
# 1      {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 13     {'addr:housenumber': '10-3891', 'phone': '+1-6...
# 16     {'toilets:wheelchair': 'no', 'wheelchair': 'li...
# 19                                 {'wheelchair': 'yes'}
# ...                                                  ...
# 17712  {'addr:housenumber': '1391', 'phone': '+1-604-...
# 17713                                                 {}
# 17714                            {'cuisine': 'japanese'}
# 17716  {'addr:housenumber': '215', 'brewery': 'Guinne...
# 17717  {'addr:housenumber': '232', 'internet_access':...
#
# [5126 rows x 6 columns]

# %% [markdown]
# # 1. Find the most frequent restaurant names.
# These will be put into our canadian_chains.txt file to help extract chains for later.

# %%
grouped_names = restaurants.groupby('name', as_index=False).agg(['count'])
grouped_names = grouped_names.iloc[:, 0:1].reset_index(drop=False)
grouped_names.columns = ['name', 'count']
grouped_names = grouped_names.sort_values('count', ascending=False)
grouped_names[:20]
# Out:
#                   name  count
# 2689         starbucks    217
# 2720            subway    177
# 3138       tim hortons    124
# 1780        mcdonald's     59
# 36                 a&w     55
# 3342        white spot     26
# 993            freshii     24
# 995   freshslice pizza     24
# 2238         pizza hut     23
# 2332           quiznos     23
# 705        dairy queen     22
# 296       blenz coffee     22
# 2089            panago     21
# 1470               kfc     20
# 330       boston pizza     18
# 396        burger king     18
# 1646    little caesars     17
# 3326           wendy's     15
# 327      booster juice     14
# 1927           nando's     14

# %% [markdown]
# # 2. Filling in empty restaurant names with googlemaps API

# %%
# Manually input some empty restaurant names 
restaurants.at[16667, 'name'] = "the boathouse" #the API cannot differentiate restaurants on different floor levels
restaurants.at[14699, 'name'] = "d'oro gelato & caffè" #API can't recognize ice-cream shops

# %%
null_rests = restaurants[restaurants.name.isnull()]

# %%
API_KEY = 'AIzaSyBoL7cjVG2VlpDv2aAchPowvLQHQc11RAA'

# %%
# Our client
gmaps = googlemaps.Client(key = API_KEY)

# %%
# First we need to get all the different 'types' for the API
amenity_np = null_rests['amenity'].to_numpy()
amenity_set = set(amenity_np.flatten())

# %%
# function that will change an amenity to a specific type that the API requires to search
def amenity_to_type(a):
    if a == 'bar':
        return a
    else:
        return 'restaurant'

# %%
# applying the function
null_rests['type'] = null_rests['amenity'].apply(amenity_to_type)
null_rests
# Out:
#              lat         lon                      timestamp     amenity name  \
# 786    49.049771 -122.319001  2019-09-02T22:08:26.000-07:00   fast_food  NaN
# 1553   49.263266 -123.110529  2014-07-11T19:59:54.000-07:00         pub  NaN
# 2046   49.229367 -123.004155  2017-03-22T04:32:05.000-07:00         bar  NaN
# 2580   49.288112 -123.114637  2017-03-18T01:54:53.000-07:00        cafe  NaN
# 3609   49.333194 -123.089975  2017-06-27T17:24:54.000-07:00        cafe  NaN
# ...          ...         ...                            ...         ...  ...
# 16332  49.040982 -123.089765  2020-04-18T23:45:02.000-07:00  restaurant  NaN
# 16520  49.050337 -122.800687  2014-05-17T04:16:00.000-07:00  restaurant  NaN
# 17089  49.312247 -122.925978  2019-07-15T07:01:57.000-07:00        cafe  NaN
# 17628  49.139018 -122.889496  2020-03-21T05:16:15.000-07:00  restaurant  NaN
# 17710  49.273230 -122.792985  2013-03-25T23:57:07.000-07:00  restaurant  NaN
#
#                                                     tags        type
# 786    {'official_name': 'Kami Sushi Enterprises', 'a...  restaurant
# 1553                                                  {}  restaurant
# 2046                        {'addr:housenumber': '1822'}         bar
# 2580                                                  {}  restaurant
# 3609                                                  {}  restaurant
# ...                                                  ...         ...
# 16332                            {'cuisine': 'japanese'}  restaurant
# 16520                               {'cuisine': 'sushi'}  restaurant
# 17089                                                 {}  restaurant
# 17628                                {'cuisine': 'thai'}  restaurant
# 17710                            {'cuisine': 'japanese'}  restaurant
#
# [62 rows x 7 columns]

# %%
def request_results(df):
    # Getting specifics needed for the request
    loc = str(df['lat']) + ',' +str(df['lon'])
    loc_type = df['type']
    first_results = gmaps.places_nearby(open_now=False,location=loc,radius = 50,type=loc_type)
    return first_results

# %%
requested_data = null_rests.apply(request_results,axis=1)

# %%
# As we can see here, each restaurant request generates multiple results, 
# and some restaurant requests generate no results at all.
# I think 50 meters is a reasonable radius, 
# so we'll exclude the remaining ~20 unnamed restaurants

pd.json_normalize(requested_data)
# Out:
#    html_attributions                                            results  \
# 0                 []  [{'business_status': 'OPERATIONAL', 'geometry'...
# 1                 []  [{'business_status': 'OPERATIONAL', 'geometry'...
# 2                 []                                                 []
# 3                 []  [{'business_status': 'OPERATIONAL', 'geometry'...
# 4                 []                                                 []
# ..               ...                                                ...
# 57                []  [{'business_status': 'OPERATIONAL', 'geometry'...
# 58                []  [{'business_status': 'OPERATIONAL', 'geometry'...
# 59                []                                                 []
# 60                []  [{'business_status': 'OPERATIONAL', 'geometry'...
# 61                []  [{'business_status': 'OPERATIONAL', 'geometry'...
#
#           status
# 0             OK
# 1             OK
# 2   ZERO_RESULTS
# 3             OK
# 4   ZERO_RESULTS
# ..           ...
# 57            OK
# 58            OK
# 59  ZERO_RESULTS
# 60            OK
# 61            OK
#
# [62 rows x 3 columns]

# %%
# Since each request generates multiple restaurants, 
# we have to select the 'first' option (which is the closest located restuarant)

# Create empty dataframe
data = []
df2 = pd.DataFrame(data)

# Count number of rows in our restaurants dataframe
index = null_rests.index
number_of_rows = len(index)

# Normalize json and obtain the data we need
for i in range(number_of_rows):
    normalized_data2 = pd.json_normalize(requested_data.iloc[i]['results'])
    if normalized_data2.empty == True:
        data.append('NaN')
    else:
        data.append(normalized_data2.iloc[0]['name']) # Obtain the first/closest located restuarant
    
df2 = df2.append(data, True)
df2
# Out:
#                                       0
# 0              Kami Sushi & Teriyaki Co
# 1               Fatburger West Broadway
# 2                                   NaN
# 3           Fatburger Waterfront Centre
# 4                                   NaN
# ..                                  ...
# 57           Kamome Japanese restaurant
# 58              Maguroguy Sushi & Grill
# 59                                  NaN
# 60                      Curry and Kabab
# 61  Red Robin Gourmet Burgers and Brews
#
# [62 rows x 1 columns]

# %%
null_rests = null_rests.reset_index()
null_rests['name'] = df2[0]

# %%
# Exclude the remaining ~20 restuarants from our dataset
null_rests = null_rests[~(null_rests.name=='NaN')]
null_rests
# Out:
#     index        lat         lon                      timestamp     amenity  \
# 0     786  49.049771 -122.319001  2019-09-02T22:08:26.000-07:00   fast_food
# 1    1553  49.263266 -123.110529  2014-07-11T19:59:54.000-07:00         pub
# 3    2580  49.288112 -123.114637  2017-03-18T01:54:53.000-07:00        cafe
# 6    4614  49.247289 -122.891137  2018-12-08T01:49:20.000-08:00  restaurant
# 7    4616  49.247365 -122.891850  2018-12-08T01:49:21.000-08:00   fast_food
# 9    4738  49.278567 -122.818866  2013-04-30T03:48:25.000-07:00  restaurant
# 10   4866  49.168659 -122.581185  2019-10-27T22:06:57.000-07:00   fast_food
# 11   5154  49.264054 -123.174910  2012-04-19T07:35:30.000-07:00  restaurant
# 12   5425  49.264337 -123.174792  2019-12-29T23:17:30.000-08:00  restaurant
# 13   5673  49.312816 -123.142755  2017-12-03T01:57:54.000-08:00   ice_cream
# 15   6591  49.303076 -123.155726  2015-08-24T12:32:07.000-07:00   fast_food
# 16   7338  49.277780 -122.794653  2019-03-30T01:10:50.000-07:00  restaurant
# 17   8097  49.089154 -123.079931  2019-07-06T07:48:56.000-07:00  restaurant
# 18   8282  49.224174 -122.941720  2011-09-26T19:18:32.000-07:00   fast_food
# 20   8298  49.265529 -122.978533  2013-09-25T07:17:47.000-07:00  restaurant
# 21   8774  49.191827 -122.844280  2012-04-30T06:44:14.000-07:00  restaurant
# 23   9192  49.243914 -122.890802  2015-08-18T03:59:07.000-07:00  restaurant
# 27   9655  49.141345 -122.865518  2014-01-24T01:24:49.000-08:00   fast_food
# 28  10341  49.239647 -122.967397  2012-08-12T04:28:53.000-07:00   fast_food
# 29  10426  49.213977 -122.921571  2012-04-11T05:26:45.000-07:00  restaurant
# 30  10839  49.253859 -123.061374  2015-06-29T22:29:49.000-07:00   fast_food
# 31  10883  49.021888 -122.807301  2020-01-03T15:51:15.000-08:00        cafe
# 34  12215  49.118045 -122.888591  2019-10-30T04:29:20.000-07:00  restaurant
# 36  12963  49.210594 -122.917341  2019-05-23T06:06:51.000-07:00  restaurant
# 37  12997  49.210819 -122.917176  2013-06-04T01:12:55.000-07:00  restaurant
# 38  13073  49.276605 -122.790244  2019-07-29T07:37:17.000-07:00  restaurant
# 39  13314  49.134042 -122.690500  2019-09-13T13:57:05.000-07:00  restaurant
# 40  13467  49.264159 -123.164402  2019-12-29T23:17:30.000-08:00  restaurant
# 43  13665  49.312564 -123.078231  2015-01-21T22:11:45.000-08:00  restaurant
# 44  13889  49.275059 -123.206665  2015-04-29T23:59:26.000-07:00   fast_food
# 45  14015  49.058438 -122.494479  2012-12-25T08:02:40.000-08:00        cafe
# 46  14018  49.058292 -122.494482  2012-12-25T08:02:41.000-08:00  restaurant
# 47  14290  49.197828 -123.178398  2015-02-14T20:54:47.000-08:00   fast_food
# 48  14477  49.269919 -123.069826  2019-04-26T03:22:06.000-07:00  restaurant
# 49  14515  49.288123 -123.140291  2019-05-10T20:02:56.000-07:00  restaurant
# 51  15361  49.272311 -123.069750  2015-12-01T02:58:27.000-08:00        cafe
# 52  15545  49.263675 -123.117796  2020-03-08T01:43:36.000-08:00  restaurant
# 55  16135  49.337816 -123.102621  2019-05-06T23:57:45.000-07:00  restaurant
# 56  16225  49.057761 -122.469702  2020-03-10T01:22:18.000-07:00  restaurant
# 57  16332  49.040982 -123.089765  2020-04-18T23:45:02.000-07:00  restaurant
# 58  16520  49.050337 -122.800687  2014-05-17T04:16:00.000-07:00  restaurant
# 60  17628  49.139018 -122.889496  2020-03-21T05:16:15.000-07:00  restaurant
# 61  17710  49.273230 -122.792985  2013-03-25T23:57:07.000-07:00  restaurant
#
#                                                  name  \
# 0                            Kami Sushi & Teriyaki Co
# 1                             Fatburger West Broadway
# 3                         Fatburger Waterfront Centre
# 6                                        Jimmys Place
# 7             Hee Rae Deung Korean Chinese Restaurant
# 9                                          Sushi Mori
# 10                                             Subway
# 11                                  Nuba in Kitsilano
# 12                                  Nuba in Kitsilano
# 13                         Prospect Point Bar & Grill
# 15                             Third Beach Concession
# 16                            Chada Thai Fine Cuisine
# 17                                            Quiznos
# 18                                             Subway
# 20                                    Sushi U Burnaby
# 21  Bozzini's Restaurant - Greek, Indian Restauran...
# 23                                         Wang Ga Ma
# 27                                      Gateway Pizza
# 28                                  Ice Cream Parlour
# 29                         Sushi Well (Okonomi Sushi)
# 30                        John Hendry Park Concession
# 31                      Jan's on the Beach Restaurant
# 34                                        Sushi Topia
# 36                                Hon's Wun-Tun House
# 37                                       Kojima Sushi
# 38                           和平饭店 Peaceful Restaurant
# 39                        Diamond Sweets & Restaurant
# 40                                        Dairy Queen
# 43                        Sushi Bella North Vancouver
# 44                           Locarno Beach Concession
# 45                Kami Sushi & Teriyaki in Aldergrove
# 46                Kami Sushi & Teriyaki in Aldergrove
# 47                                     Hanami Express
# 48                   Lombardo's Pizzeria & Ristorante
# 49                                   Fatburger Denman
# 51                                     Cafe Du Soleil
# 52                    Cactus Club Cafe Broadway + Ash
# 55                             Edgemont Gourmet Meats
# 56                     Ocean Park Pizza & Steak House
# 57                         Kamome Japanese restaurant
# 58                            Maguroguy Sushi & Grill
# 60                                    Curry and Kabab
# 61                Red Robin Gourmet Burgers and Brews
#
#                                                  tags        type
# 0   {'official_name': 'Kami Sushi Enterprises', 'a...  restaurant
# 1                                                  {}  restaurant
# 3                                                  {}  restaurant
# 6                                                  {}  restaurant
# 7                                                  {}  restaurant
# 9                                {'cuisine': 'greek'}  restaurant
# 10  {'cuisine': 'sandwich', 'level': '0', 'takeawa...  restaurant
# 11                            {'cuisine': 'japanese'}  restaurant
# 12                                                 {}  restaurant
# 13                                                 {}  restaurant
# 15                      {'source': 'local_knowledge'}  restaurant
# 16                                {'cuisine': 'thai'}  restaurant
# 17                             {'cuisine': 'chinese'}  restaurant
# 18                               {'cuisine': 'pizza'}  restaurant
# 20                                                 {}  restaurant
# 21                                                 {}  restaurant
# 23                                                 {}  restaurant
# 27                        {'cuisine': 'indian;pizza'}  restaurant
# 28                                                 {}  restaurant
# 29                               {'cuisine': 'sushi'}  restaurant
# 30                                                 {}  restaurant
# 31  {'addr:housenumber': '14973', 'website': 'http...  restaurant
# 34                               {'cuisine': 'sushi'}  restaurant
# 36  {'cuisine': 'korean', 'addr:housenumber': '412...  restaurant
# 37  {'entrance': 'yes', 'note': 'no longer fish an...  restaurant
# 38                             {'cuisine': 'chinese'}  restaurant
# 39       {'cuisine': 'indian', 'addr:city': 'Surrey'}  restaurant
# 40                                                 {}  restaurant
# 43                             {'cuisine': 'seafood'}  restaurant
# 44                                                 {}  restaurant
# 45                                                 {}  restaurant
# 46                               {'cuisine': 'sushi'}  restaurant
# 47                               {'cuisine': 'asian'}  restaurant
# 48    {'name:de': 'Lombardo's Pizzeria & Ristorante'}  restaurant
# 49  {'name:it': 'Amici miei italian', 'addr:housen...  restaurant
# 51                              {'cuisine': 'german'}  restaurant
# 52  {'cuisine': 'japanese', 'addr:street': 'West B...  restaurant
# 55                                                 {}  restaurant
# 56                                {'cuisine': 'thai'}  restaurant
# 57                            {'cuisine': 'japanese'}  restaurant
# 58                               {'cuisine': 'sushi'}  restaurant
# 60                                {'cuisine': 'thai'}  restaurant
# 61                            {'cuisine': 'japanese'}  restaurant

# %%
# Add in all restuarants
restaurants = restaurants[~restaurants.name.isnull()]
restaurants = restaurants.append(null_rests)
restaurants
# Out:
#           lat         lon                      timestamp     amenity  \
# 0   49.260812 -123.125736  2020-03-20T18:22:12.000-07:00        cafe
# 1   49.260953 -123.125704  2019-08-02T18:11:20.000-07:00   fast_food
# 13  49.126650 -123.182470  2020-03-30T09:08:51.000-07:00  restaurant
# 16  49.283192 -123.109050  2015-12-18T21:41:07.000-08:00         pub
# 19  49.265951 -123.246630  2011-11-19T08:06:36.000-08:00         pub
# ..        ...         ...                            ...         ...
# 56  49.057761 -122.469702  2020-03-10T01:22:18.000-07:00  restaurant
# 57  49.040982 -123.089765  2020-04-18T23:45:02.000-07:00  restaurant
# 58  49.050337 -122.800687  2014-05-17T04:16:00.000-07:00  restaurant
# 60  49.139018 -122.889496  2020-03-21T05:16:15.000-07:00  restaurant
# 61  49.273230 -122.792985  2013-03-25T23:57:07.000-07:00  restaurant
#
#                                    name  \
# 0                             starbucks
# 1                            salad loop
# 13             best bite indian cuisine
# 16                           the cambie
# 19                      mahony and sons
# ..                                  ...
# 56       Ocean Park Pizza & Steak House
# 57           Kamome Japanese restaurant
# 58              Maguroguy Sushi & Grill
# 60                      Curry and Kabab
# 61  Red Robin Gourmet Burgers and Brews
#
#                                                  tags    index        type
# 0   {'brand:wikidata': 'Q37158', 'official_name': ...      NaN         NaN
# 1   {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...      NaN         NaN
# 13  {'addr:housenumber': '10-3891', 'phone': '+1-6...      NaN         NaN
# 16  {'toilets:wheelchair': 'no', 'wheelchair': 'li...      NaN         NaN
# 19                              {'wheelchair': 'yes'}      NaN         NaN
# ..                                                ...      ...         ...
# 56                                {'cuisine': 'thai'}  16225.0  restaurant
# 57                            {'cuisine': 'japanese'}  16332.0  restaurant
# 58                               {'cuisine': 'sushi'}  16520.0  restaurant
# 60                                {'cuisine': 'thai'}  17628.0  restaurant
# 61                            {'cuisine': 'japanese'}  17710.0  restaurant
#
# [5107 rows x 8 columns]

# %%
# Cleaning up
restaurants = restaurants.reset_index()
restaurants = restaurants.drop(['index', 'type', 'level_0'], axis=1)
restaurants
# Out:
#             lat         lon                      timestamp     amenity  \
# 0     49.260812 -123.125736  2020-03-20T18:22:12.000-07:00        cafe
# 1     49.260953 -123.125704  2019-08-02T18:11:20.000-07:00   fast_food
# 2     49.126650 -123.182470  2020-03-30T09:08:51.000-07:00  restaurant
# 3     49.283192 -123.109050  2015-12-18T21:41:07.000-08:00         pub
# 4     49.265951 -123.246630  2011-11-19T08:06:36.000-08:00         pub
# ...         ...         ...                            ...         ...
# 5102  49.057761 -122.469702  2020-03-10T01:22:18.000-07:00  restaurant
# 5103  49.040982 -123.089765  2020-04-18T23:45:02.000-07:00  restaurant
# 5104  49.050337 -122.800687  2014-05-17T04:16:00.000-07:00  restaurant
# 5105  49.139018 -122.889496  2020-03-21T05:16:15.000-07:00  restaurant
# 5106  49.273230 -122.792985  2013-03-25T23:57:07.000-07:00  restaurant
#
#                                      name  \
# 0                               starbucks
# 1                              salad loop
# 2                best bite indian cuisine
# 3                              the cambie
# 4                         mahony and sons
# ...                                   ...
# 5102       Ocean Park Pizza & Steak House
# 5103           Kamome Japanese restaurant
# 5104              Maguroguy Sushi & Grill
# 5105                      Curry and Kabab
# 5106  Red Robin Gourmet Burgers and Brews
#
#                                                    tags
# 0     {'brand:wikidata': 'Q37158', 'official_name': ...
# 1     {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 2     {'addr:housenumber': '10-3891', 'phone': '+1-6...
# 3     {'toilets:wheelchair': 'no', 'wheelchair': 'li...
# 4                                 {'wheelchair': 'yes'}
# ...                                                 ...
# 5102                                {'cuisine': 'thai'}
# 5103                            {'cuisine': 'japanese'}
# 5104                               {'cuisine': 'sushi'}
# 5105                                {'cuisine': 'thai'}
# 5106                            {'cuisine': 'japanese'}
#
# [5107 rows x 6 columns]

# %%
restaurants.to_csv('complete_restaurants.csv')

# %% [markdown]
# # 3. Find the postal codes with googlemaps API
# Please view find_postal_codes.ipynb to see this code. Since the API request takes 15-30 minutes, we've put it in a separate notebook file for your convenience. find_postal_codes.ipynb inputs the CSV file above and outputs the CSV file below.

# %%
restaurants = pd.read_csv('complete_restaurants_WITH_ADDRESS.csv')

# %% [markdown]
# # 4. Inner join with postalcodes.csv

# %%
postaldf = pd.read_csv('postalcodes.csv')
postaldf
# Out:
#     Code               Place            Admin1    Admin2
# 0    V3H          Port Moody  British Columbia       NaN
# 1    V3Y        Pitt Meadows  British Columbia       NaN
# 2    V4B          White Rock  British Columbia       NaN
# 3    V4T            Westbank  British Columbia       NaN
# 4    V4V            Winfield  British Columbia       NaN
# ..   ...                 ...               ...       ...
# 187  V1B         Vernon East  British Columbia    Vernon
# 188  V1C           Cranbrook  British Columbia       NaN
# 189  V1G        Dawson Creek  British Columbia       NaN
# 190  V1K             Merritt  British Columbia       NaN
# 191  V2B  Kamloops Northwest  British Columbia  Kamloops
#
# [192 rows x 4 columns]

# %%
restaurants = restaurants.rename(columns={'postal code': 'Code'})

# %%
restaurants['Code']=restaurants['Code'].astype(str)
postaldf['Code']=postaldf['Code'].astype(str)
restaurants = restaurants.merge(postaldf, on='Code')

# %%
restaurants = restaurants.drop(['Unnamed: 0','Admin1', 'Admin2'], axis=1)
restaurants
# Out:
#             lat         lon                      timestamp     amenity  \
# 0     49.260812 -123.125736  2020-03-20T18:22:12.000-07:00        cafe
# 1     49.260953 -123.125704  2019-08-02T18:11:20.000-07:00   fast_food
# 2     49.263582 -123.128836  2019-05-04T04:55:51.000-07:00        cafe
# 3     49.263537 -123.127195  2019-09-02T22:08:25.000-07:00  restaurant
# 4     49.263646 -123.131694  2019-09-13T13:56:49.000-07:00  restaurant
# ...         ...         ...                            ...         ...
# 5096  49.025522 -123.067520  2020-04-28T00:17:48.000-07:00  restaurant
# 5097  49.250815 -123.168021  2018-02-09T05:00:19.000-08:00   fast_food
# 5098  49.187647 -122.552271  2016-01-26T23:05:26.000-08:00        cafe
# 5099  49.187668 -122.551942  2016-01-26T23:05:26.000-08:00  restaurant
# 5100  49.336274 -123.038733  2016-02-18T19:45:13.000-08:00        cafe
#
#                             name  \
# 0                      starbucks
# 1                     salad loop
# 2                          waves
# 3     minato japanese restaurant
# 4              royal seoul house
# ...                          ...
# 5096                chopped leaf
# 5097                ridge garden
# 5098         kanaka creek coffee
# 5099                       pizza
# 5100             delany's coffee
#
#                                                    tags  \
# 0     {'brand:wikidata': 'Q37158', 'official_name': ...
# 1     {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 2     {'opening_hours': 'Mo-Fr 06:00-24:00; Sa-Su 08...
# 3     {'opening_hours': 'Mo-Fr 11:30-21:00; Sa 16:30...
# 4     {'addr:housenumber': '1215', 'phone': '+1-604-...
# ...                                                 ...
# 5096  {'addr:province': 'BC', 'addr:housenumber': '1...
# 5097  {'addr:housenumber': '4009', 'phone': '+1-604-...
# 5098                                                 {}
# 5099                               {'cuisine': 'pizza'}
# 5100                                                 {}
#
#                                                 address Code  \
# 0        1001 W 12th Ave, Vancouver, BC V6H 0A5, Canada  V6H
# 1        1001 W 12th Ave, Vancouver, BC V6H 0A5, Canada  V6H
# 2              1095 BC-7, Vancouver, BC V6H 0A8, Canada  V6H
# 3       1001w W Broadway, Vancouver, BC V6H 4E4, Canada  V6H
# 4        1215 W Broadway, Vancouver, BC V6H 1G7, Canada  V6H
# ...                                                 ...  ...
# 5096              1236 56 St, Delta, BC V4L 2A4, Canada  V4L
# 5097   4017 Macdonald St, Vancouver, BC V6L 2N8, Canada  V6L
# 5098     24155 102 Ave, Maple Ridge, BC V2W 2C6, Canada  V2W
# 5099     24167 102 Ave, Maple Ridge, BC V2W 2C6, Canada  V2W
# 5100  1233 - 1277 Lynn Valley Rd, North Vancouver, B...  V7K
#
#                                                   Place
# 0     Vancouver (West Fairview / Granville Island / ...
# 1     Vancouver (West Fairview / Granville Island / ...
# 2     Vancouver (West Fairview / Granville Island / ...
# 3     Vancouver (West Fairview / Granville Island / ...
# 4     Vancouver (West Fairview / Granville Island / ...
# ...                                                 ...
# 5096                                    Delta Southeast
# 5097                       Vancouver (NW Arbutus Ridge)
# 5098                                   Maple Ridge East
# 5099                                   Maple Ridge East
# 5100                      North Vancouver North Central
#
# [5101 rows x 9 columns]

# %% [markdown]
# # 5. Extract cuisine type from tags

# %%
# Ignored several rows with zero counts of chain restaurants or independent restaurants.
def get_cuisine(tagDict):
    tagDict = eval(tagDict)
    if "cuisine" in tagDict:
        return tagDict['cuisine']

restaurants['cuisine'] = restaurants['tags'].apply(get_cuisine)
# 2412 rows (about half) do not have a cuisine and are None.

# %% [markdown]
# # 6. Extract chain restaurants using fuzzy matching

# %%
# Load the text file of the list of chain restaurants.
# This list contains the top 20 most frequent restaurant names,
# as well as chains from the following Wikipedia pages:

# https://en.wikipedia.org/wiki/List_of_Canadian_restaurant_chains
# https://en.wikipedia.org/wiki/List_of_fast-food_chains_in_Canada
# https://en.wikipedia.org/wiki/List_of_Canadian_pizza_chains

chains_text = open("canadian_chains.txt", "r")
chainList = chains_text.read().split('\n')
chainList = [item.lower() for item in chainList]

# %%
# Match names to the list of chains.
matchList = []
ratioList = []
def match_chains(str2Match):
    ratio = process.extractOne(str2Match, chainList, scorer=fuzz.token_set_ratio, score_cutoff=91)
    if ratio == None:
        matchList.append(None)
        ratioList.append(None)
    else:
        matchList.append(ratio[0])
        ratioList.append(ratio[1])
    
ratios = np.vectorize(match_chains,otypes=[tuple])(restaurants['name'])

restaurants['match'] = matchList
restaurants['ratio'] = ratioList

# %%
indiedf = restaurants[(restaurants['match'].isnull())]
indiedf
# Out:
#             lat         lon                      timestamp     amenity  \
# 1     49.260953 -123.125704  2019-08-02T18:11:20.000-07:00   fast_food
# 3     49.263537 -123.127195  2019-09-02T22:08:25.000-07:00  restaurant
# 4     49.263646 -123.131694  2019-09-13T13:56:49.000-07:00  restaurant
# 5     49.272632 -123.135369  2020-02-27T21:56:22.000-08:00   fast_food
# 6     49.272661 -123.135317  2020-02-27T21:56:22.000-08:00   fast_food
# ...         ...         ...                            ...         ...
# 5092  49.033067 -123.069255  2019-08-18T09:07:49.000-07:00  restaurant
# 5095  49.024524 -123.066485  2019-08-18T20:56:16.000-07:00        cafe
# 5097  49.250815 -123.168021  2018-02-09T05:00:19.000-08:00   fast_food
# 5098  49.187647 -122.552271  2016-01-26T23:05:26.000-08:00        cafe
# 5100  49.336274 -123.038733  2016-02-18T19:45:13.000-08:00        cafe
#
#                             name  \
# 1                     salad loop
# 3     minato japanese restaurant
# 4              royal seoul house
# 5            fraser valley juice
# 6                    pizza pzazz
# ...                          ...
# 5092          browns socialhouse
# 5095  wood n frog coffee company
# 5097                ridge garden
# 5098         kanaka creek coffee
# 5100             delany's coffee
#
#                                                    tags  \
# 1     {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 3     {'opening_hours': 'Mo-Fr 11:30-21:00; Sa 16:30...
# 4     {'addr:housenumber': '1215', 'phone': '+1-604-...
# 5                 {'indoor': 'yes', 'addr:unit': '113'}
# 6     {'cuisine': 'pizza', 'indoor': 'yes', 'phone':...
# ...                                                 ...
# 5092                                                 {}
# 5095                                                 {}
# 5097  {'addr:housenumber': '4009', 'phone': '+1-604-...
# 5098                                                 {}
# 5100                                                 {}
#
#                                                 address Code  \
# 1        1001 W 12th Ave, Vancouver, BC V6H 0A5, Canada  V6H
# 3       1001w W Broadway, Vancouver, BC V6H 4E4, Canada  V6H
# 4        1215 W Broadway, Vancouver, BC V6H 1G7, Canada  V6H
# 5       1590 Johnston St, Vancouver, BC V6H 3R5, Canada  V6H
# 6       1689 Johnston St, Vancouver, BC V6H 3R9, Canada  V6H
# ...                                                 ...  ...
# 5092              1665 56 St, Delta, BC V4L 2B2, Canada  V4L
# 5095             5694 12 Ave, Delta, BC V4L 1C4, Canada  V4L
# 5097   4017 Macdonald St, Vancouver, BC V6L 2N8, Canada  V6L
# 5098     24155 102 Ave, Maple Ridge, BC V2W 2C6, Canada  V2W
# 5100  1233 - 1277 Lynn Valley Rd, North Vancouver, B...  V7K
#
#                                                   Place  cuisine match  ratio
# 1     Vancouver (West Fairview / Granville Island / ...     None  None    NaN
# 3     Vancouver (West Fairview / Granville Island / ...    sushi  None    NaN
# 4     Vancouver (West Fairview / Granville Island / ...   korean  None    NaN
# 5     Vancouver (West Fairview / Granville Island / ...     None  None    NaN
# 6     Vancouver (West Fairview / Granville Island / ...    pizza  None    NaN
# ...                                                 ...      ...   ...    ...
# 5092                                    Delta Southeast     None  None    NaN
# 5095                                    Delta Southeast     None  None    NaN
# 5097                       Vancouver (NW Arbutus Ridge)  chinese  None    NaN
# 5098                                   Maple Ridge East     None  None    NaN
# 5100                      North Vancouver North Central     None  None    NaN
#
# [3543 rows x 12 columns]

# %%
indiedf = indiedf.drop(['match', 'ratio'], axis=1)

# %%
chainsdf = restaurants[~(restaurants['match'].isnull())]
chainsdf
# Out:
#             lat         lon                      timestamp     amenity  \
# 0     49.260812 -123.125736  2020-03-20T18:22:12.000-07:00        cafe
# 2     49.263582 -123.128836  2019-05-04T04:55:51.000-07:00        cafe
# 7     49.263448 -123.138067  2019-09-02T22:08:25.000-07:00   fast_food
# 9     49.263225 -123.133390  2019-08-29T18:25:42.000-07:00  restaurant
# 10    49.271156 -123.135808  2019-08-29T18:31:06.000-07:00  restaurant
# ...         ...         ...                            ...         ...
# 5090  49.027368 -123.068977  2019-08-18T11:22:44.000-07:00        cafe
# 5093  49.030851 -123.069185  2019-08-18T10:15:50.000-07:00   fast_food
# 5094  49.031154 -123.069197  2019-08-18T10:15:50.000-07:00  restaurant
# 5096  49.025522 -123.067520  2020-04-28T00:17:48.000-07:00  restaurant
# 5099  49.187668 -122.551942  2016-01-26T23:05:26.000-08:00  restaurant
#
#               name                                               tags  \
# 0        starbucks  {'brand:wikidata': 'Q37158', 'official_name': ...
# 2            waves  {'opening_hours': 'Mo-Fr 06:00-24:00; Sa-Su 08...
# 7       mcdonald's  {'brand:wikidata': 'Q38076', 'addr:housenumber...
# 9          denny's  {'brand:wikidata': 'Q1189695', 'addr:housenumb...
# 10         the keg  {'brand:wikidata': 'Q7744066', 'wheelchair': '...
# ...            ...                                                ...
# 5090     starbucks  {'brand:wikidata': 'Q37158', 'official_name': ...
# 5093   dairy queen  {'brand:wikidata': 'Q1141226', 'cuisine': 'ice...
# 5094     pizza hut  {'brand:wikidata': 'Q191615', 'cuisine': 'pizz...
# 5096  chopped leaf  {'addr:province': 'BC', 'addr:housenumber': '1...
# 5099         pizza                               {'cuisine': 'pizza'}
#
#                                                address Code  \
# 0       1001 W 12th Ave, Vancouver, BC V6H 0A5, Canada  V6H
# 2             1095 BC-7, Vancouver, BC V6H 0A8, Canada  V6H
# 7             1482 BC-7, Vancouver, BC V6H 4E8, Canada  V6H
# 9       1296 W Broadway, Vancouver, BC V6H 1G6, Canada  V6H
# 10    1499 Duranleau St, Vancouver, BC V6H 3S3, Canada  V6H
# ...                                                ...  ...
# 5090           1-1359 56 St, Delta, BC V4L 2A2, Canada  V4L
# 5093             1555 56 St, Delta, BC V4L 2A9, Canada  V4L
# 5094             1561 56 St, Delta, BC V4L 2A9, Canada  V4L
# 5096             1236 56 St, Delta, BC V4L 2A4, Canada  V4L
# 5099    24167 102 Ave, Maple Ridge, BC V2W 2C6, Canada  V2W
#
#                                                   Place           cuisine  \
# 0     Vancouver (West Fairview / Granville Island / ...       coffee_shop
# 2     Vancouver (West Fairview / Granville Island / ...              None
# 7     Vancouver (West Fairview / Granville Island / ...            burger
# 9     Vancouver (West Fairview / Granville Island / ...          american
# 10    Vancouver (West Fairview / Granville Island / ...       steak_house
# ...                                                 ...               ...
# 5090                                    Delta Southeast       coffee_shop
# 5093                                    Delta Southeast  ice_cream;burger
# 5094                                    Delta Southeast             pizza
# 5096                                    Delta Southeast              None
# 5099                                   Maple Ridge East             pizza
#
#              match  ratio
# 0        starbucks  100.0
# 2            waves  100.0
# 7       mcdonald's  100.0
# 9          denny's  100.0
# 10         the keg  100.0
# ...            ...    ...
# 5090     starbucks  100.0
# 5093   dairy queen  100.0
# 5094     pizza hut  100.0
# 5096  chopped leaf  100.0
# 5099     241 pizza  100.0
#
# [1558 rows x 12 columns]

# %%
chainsdf = chainsdf.drop(['match', 'ratio'], axis=1)

# %%
indiedf['is chain'] = False
indiedf
# Out:
#             lat         lon                      timestamp     amenity  \
# 1     49.260953 -123.125704  2019-08-02T18:11:20.000-07:00   fast_food
# 3     49.263537 -123.127195  2019-09-02T22:08:25.000-07:00  restaurant
# 4     49.263646 -123.131694  2019-09-13T13:56:49.000-07:00  restaurant
# 5     49.272632 -123.135369  2020-02-27T21:56:22.000-08:00   fast_food
# 6     49.272661 -123.135317  2020-02-27T21:56:22.000-08:00   fast_food
# ...         ...         ...                            ...         ...
# 5092  49.033067 -123.069255  2019-08-18T09:07:49.000-07:00  restaurant
# 5095  49.024524 -123.066485  2019-08-18T20:56:16.000-07:00        cafe
# 5097  49.250815 -123.168021  2018-02-09T05:00:19.000-08:00   fast_food
# 5098  49.187647 -122.552271  2016-01-26T23:05:26.000-08:00        cafe
# 5100  49.336274 -123.038733  2016-02-18T19:45:13.000-08:00        cafe
#
#                             name  \
# 1                     salad loop
# 3     minato japanese restaurant
# 4              royal seoul house
# 5            fraser valley juice
# 6                    pizza pzazz
# ...                          ...
# 5092          browns socialhouse
# 5095  wood n frog coffee company
# 5097                ridge garden
# 5098         kanaka creek coffee
# 5100             delany's coffee
#
#                                                    tags  \
# 1     {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 3     {'opening_hours': 'Mo-Fr 11:30-21:00; Sa 16:30...
# 4     {'addr:housenumber': '1215', 'phone': '+1-604-...
# 5                 {'indoor': 'yes', 'addr:unit': '113'}
# 6     {'cuisine': 'pizza', 'indoor': 'yes', 'phone':...
# ...                                                 ...
# 5092                                                 {}
# 5095                                                 {}
# 5097  {'addr:housenumber': '4009', 'phone': '+1-604-...
# 5098                                                 {}
# 5100                                                 {}
#
#                                                 address Code  \
# 1        1001 W 12th Ave, Vancouver, BC V6H 0A5, Canada  V6H
# 3       1001w W Broadway, Vancouver, BC V6H 4E4, Canada  V6H
# 4        1215 W Broadway, Vancouver, BC V6H 1G7, Canada  V6H
# 5       1590 Johnston St, Vancouver, BC V6H 3R5, Canada  V6H
# 6       1689 Johnston St, Vancouver, BC V6H 3R9, Canada  V6H
# ...                                                 ...  ...
# 5092              1665 56 St, Delta, BC V4L 2B2, Canada  V4L
# 5095             5694 12 Ave, Delta, BC V4L 1C4, Canada  V4L
# 5097   4017 Macdonald St, Vancouver, BC V6L 2N8, Canada  V6L
# 5098     24155 102 Ave, Maple Ridge, BC V2W 2C6, Canada  V2W
# 5100  1233 - 1277 Lynn Valley Rd, North Vancouver, B...  V7K
#
#                                                   Place  cuisine  is chain
# 1     Vancouver (West Fairview / Granville Island / ...     None     False
# 3     Vancouver (West Fairview / Granville Island / ...    sushi     False
# 4     Vancouver (West Fairview / Granville Island / ...   korean     False
# 5     Vancouver (West Fairview / Granville Island / ...     None     False
# 6     Vancouver (West Fairview / Granville Island / ...    pizza     False
# ...                                                 ...      ...       ...
# 5092                                    Delta Southeast     None     False
# 5095                                    Delta Southeast     None     False
# 5097                       Vancouver (NW Arbutus Ridge)  chinese     False
# 5098                                   Maple Ridge East     None     False
# 5100                      North Vancouver North Central     None     False
#
# [3543 rows x 11 columns]

# %%
chainsdf['is chain'] = True
chainsdf
# Out:
#             lat         lon                      timestamp     amenity  \
# 0     49.260812 -123.125736  2020-03-20T18:22:12.000-07:00        cafe
# 2     49.263582 -123.128836  2019-05-04T04:55:51.000-07:00        cafe
# 7     49.263448 -123.138067  2019-09-02T22:08:25.000-07:00   fast_food
# 9     49.263225 -123.133390  2019-08-29T18:25:42.000-07:00  restaurant
# 10    49.271156 -123.135808  2019-08-29T18:31:06.000-07:00  restaurant
# ...         ...         ...                            ...         ...
# 5090  49.027368 -123.068977  2019-08-18T11:22:44.000-07:00        cafe
# 5093  49.030851 -123.069185  2019-08-18T10:15:50.000-07:00   fast_food
# 5094  49.031154 -123.069197  2019-08-18T10:15:50.000-07:00  restaurant
# 5096  49.025522 -123.067520  2020-04-28T00:17:48.000-07:00  restaurant
# 5099  49.187668 -122.551942  2016-01-26T23:05:26.000-08:00  restaurant
#
#               name                                               tags  \
# 0        starbucks  {'brand:wikidata': 'Q37158', 'official_name': ...
# 2            waves  {'opening_hours': 'Mo-Fr 06:00-24:00; Sa-Su 08...
# 7       mcdonald's  {'brand:wikidata': 'Q38076', 'addr:housenumber...
# 9          denny's  {'brand:wikidata': 'Q1189695', 'addr:housenumb...
# 10         the keg  {'brand:wikidata': 'Q7744066', 'wheelchair': '...
# ...            ...                                                ...
# 5090     starbucks  {'brand:wikidata': 'Q37158', 'official_name': ...
# 5093   dairy queen  {'brand:wikidata': 'Q1141226', 'cuisine': 'ice...
# 5094     pizza hut  {'brand:wikidata': 'Q191615', 'cuisine': 'pizz...
# 5096  chopped leaf  {'addr:province': 'BC', 'addr:housenumber': '1...
# 5099         pizza                               {'cuisine': 'pizza'}
#
#                                                address Code  \
# 0       1001 W 12th Ave, Vancouver, BC V6H 0A5, Canada  V6H
# 2             1095 BC-7, Vancouver, BC V6H 0A8, Canada  V6H
# 7             1482 BC-7, Vancouver, BC V6H 4E8, Canada  V6H
# 9       1296 W Broadway, Vancouver, BC V6H 1G6, Canada  V6H
# 10    1499 Duranleau St, Vancouver, BC V6H 3S3, Canada  V6H
# ...                                                ...  ...
# 5090           1-1359 56 St, Delta, BC V4L 2A2, Canada  V4L
# 5093             1555 56 St, Delta, BC V4L 2A9, Canada  V4L
# 5094             1561 56 St, Delta, BC V4L 2A9, Canada  V4L
# 5096             1236 56 St, Delta, BC V4L 2A4, Canada  V4L
# 5099    24167 102 Ave, Maple Ridge, BC V2W 2C6, Canada  V2W
#
#                                                   Place           cuisine  \
# 0     Vancouver (West Fairview / Granville Island / ...       coffee_shop
# 2     Vancouver (West Fairview / Granville Island / ...              None
# 7     Vancouver (West Fairview / Granville Island / ...            burger
# 9     Vancouver (West Fairview / Granville Island / ...          american
# 10    Vancouver (West Fairview / Granville Island / ...       steak_house
# ...                                                 ...               ...
# 5090                                    Delta Southeast       coffee_shop
# 5093                                    Delta Southeast  ice_cream;burger
# 5094                                    Delta Southeast             pizza
# 5096                                    Delta Southeast              None
# 5099                                   Maple Ridge East             pizza
#
#       is chain
# 0         True
# 2         True
# 7         True
# 9         True
# 10        True
# ...        ...
# 5090      True
# 5093      True
# 5094      True
# 5096      True
# 5099      True
#
# [1558 rows x 11 columns]

# %%
final_restaurants = chainsdf.append(indiedf) 
final_restaurants = final_restaurants.drop(['timestamp'], axis=1)

# %%
final_restaurants.to_csv('final_restaurants.csv')
final_restaurants
# Out:
#             lat         lon     amenity                        name  \
# 0     49.260812 -123.125736        cafe                   starbucks
# 2     49.263582 -123.128836        cafe                       waves
# 7     49.263448 -123.138067   fast_food                  mcdonald's
# 9     49.263225 -123.133390  restaurant                     denny's
# 10    49.271156 -123.135808  restaurant                     the keg
# ...         ...         ...         ...                         ...
# 5092  49.033067 -123.069255  restaurant          browns socialhouse
# 5095  49.024524 -123.066485        cafe  wood n frog coffee company
# 5097  49.250815 -123.168021   fast_food                ridge garden
# 5098  49.187647 -122.552271        cafe         kanaka creek coffee
# 5100  49.336274 -123.038733        cafe             delany's coffee
#
#                                                    tags  \
# 0     {'brand:wikidata': 'Q37158', 'official_name': ...
# 2     {'opening_hours': 'Mo-Fr 06:00-24:00; Sa-Su 08...
# 7     {'brand:wikidata': 'Q38076', 'addr:housenumber...
# 9     {'brand:wikidata': 'Q1189695', 'addr:housenumb...
# 10    {'brand:wikidata': 'Q7744066', 'wheelchair': '...
# ...                                                 ...
# 5092                                                 {}
# 5095                                                 {}
# 5097  {'addr:housenumber': '4009', 'phone': '+1-604-...
# 5098                                                 {}
# 5100                                                 {}
#
#                                                 address Code  \
# 0        1001 W 12th Ave, Vancouver, BC V6H 0A5, Canada  V6H
# 2              1095 BC-7, Vancouver, BC V6H 0A8, Canada  V6H
# 7              1482 BC-7, Vancouver, BC V6H 4E8, Canada  V6H
# 9        1296 W Broadway, Vancouver, BC V6H 1G6, Canada  V6H
# 10     1499 Duranleau St, Vancouver, BC V6H 3S3, Canada  V6H
# ...                                                 ...  ...
# 5092              1665 56 St, Delta, BC V4L 2B2, Canada  V4L
# 5095             5694 12 Ave, Delta, BC V4L 1C4, Canada  V4L
# 5097   4017 Macdonald St, Vancouver, BC V6L 2N8, Canada  V6L
# 5098     24155 102 Ave, Maple Ridge, BC V2W 2C6, Canada  V2W
# 5100  1233 - 1277 Lynn Valley Rd, North Vancouver, B...  V7K
#
#                                                   Place      cuisine  is chain
# 0     Vancouver (West Fairview / Granville Island / ...  coffee_shop      True
# 2     Vancouver (West Fairview / Granville Island / ...         None      True
# 7     Vancouver (West Fairview / Granville Island / ...       burger      True
# 9     Vancouver (West Fairview / Granville Island / ...     american      True
# 10    Vancouver (West Fairview / Granville Island / ...  steak_house      True
# ...                                                 ...          ...       ...
# 5092                                    Delta Southeast         None     False
# 5095                                    Delta Southeast         None     False
# 5097                       Vancouver (NW Arbutus Ridge)      chinese     False
# 5098                                   Maple Ridge East         None     False
# 5100                      North Vancouver North Central         None     False
#
# [5101 rows x 10 columns]

# %% [markdown]
# # 7. Find ratings, total user ratings, price levels and place ID's with googlemaps API
# Please view get_all_restaurant_ratings.ipynb to see this code. Since the API request takes 15-30 minutes, we've put it in a separate notebook file for your convenience. get_all_restaurant_ratings.ipynb inputs the CSV file above and outputs final_restaurants_v2.csv.

# %% [markdown]
# # 8. Feature engineering, use label encoding and hot encoding
# Please view label_and_hot_encoding.ipynb to see this code. label_and_hot_encoding.ipynb inputs final_restaurants_v2.csv and outputs hot_encoded_rests.csv.
